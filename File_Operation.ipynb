# %% [markdown]
# <a href="https://colab.research.google.com/github/KRubasri/Python-programming-laboratory-/blob/main/File_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # File Operation

# %%
try:
  num1 = int(input("Enter a number:"))
  num2 = int(input("Enter another number:"))
  result = num1 / num2
  print("Result:", result)
except ZeroDivisionError:
  print("Error: You cannot divide by zero.")
except ValueError:
  print("Error: Please enter numbers only.")
else:
  print("Result:",result)
finally:
  print("Program execution completed.")
# Out:
# Enter a number:10
# Enter another number:10
# Result: 1.0
# Result: 1.0
# Program execution completed.

# %% [markdown]
# # Types

# %%
print("Demonstration of common Python Exceptions\n")

#1 ZeroDivisionError
try:
  print(10/0)
except ZeroDivisionError:
  print("X ZeroDivisionError: You cannot divide by zero.\n")

#2 ValueError
try:
  num = int("abc")
except ValueError:
  print("X ValueError: Cannot convert string to integer.\n")

  #3 TypeError
  try:
    result="2" + 2
  except TypeError:
    print("X TypeError: You tried to add string and integer.\n")

    #4 IndexError
    try:
      lst=[1,2,3]
      print(lst[3])
    except IndexError:
      print("X IndexError: List index out of range.\n")

      #5 KeyError
      try:
        my_dict = {'name': 'Anu'}
        print(my_dict['age'])
      except KeyError:
        print("X KeyError: Key not found in dictionary.\n")
# Out:
# Demonstration of common Python Exceptions
#
# X ZeroDivisionError: You cannot divide by zero.
#
# X ValueError: Cannot convert string to integer.
#
# X TypeError: You tried to add string and integer.
#
# X IndexError: List index out of range.
#
# X KeyError: Key not found in dictionary.
